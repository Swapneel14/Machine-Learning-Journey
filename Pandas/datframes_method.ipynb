# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()
# Out:
# Player_of_Match
# F du Plessis         3
# SK Raina             3
# KA Pollard           3
# JJ Bumrah            2
# AB de Villiers       2
# MK Pandey            2
# M Vijay              2
# A Kumble             2
# YK Pathan            2
# SR Watson            2
# HH Pandya            1
# RM Patidar           1
# JC Buttler           1
# RR Pant              1
# KS Williamson        1
# MP Stoinis           1
# TA Boult             1
# SP Narine            1
# RD Gaikwad           1
# VR Iyer              1
# DA Miller            1
# Washington Sundar    1
# NM Coulter-Nile      1
# KV Sharma            1
# BCJ Cutting          1
# KH Pandya            1
# SA Yadav             1
# Rashid Khan          1
# AD Russell           1
# RG Sharma            1
# A Nehra              1
# DA Warner            1
# MC Henriques         1
# Harbhajan Singh      1
# BJ Hodge             1
# UT Yadav             1
# V Sehwag             1
# MS Bisla             1
# MEK Hussey           1
# ...

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
#Matches Played by Each Team
ipl['Team1'].value_counts()+ipl['Team2'].value_counts()
# Out:
# Chennai Super Kings            208
# Deccan Chargers                 75
# Delhi Capitals                  63
# Delhi Daredevils               161
# Gujarat Lions                   30
# Gujarat Titans                  16
# Kings XI Punjab                190
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          223
# Lucknow Super Giants            15
# Mumbai Indians                 231
# Pune Warriors                   46
# Punjab Kings                    28
# Rajasthan Royals               192
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    226
# Sunrisers Hyderabad            152
# Name: count, dtype: int64

# %%
#sort_values()
movies = pd.read_csv('movies.csv')
movies.sort_values('title_x',ascending=False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
df = pd.DataFrame({
    "ID": [1, 2, 3, 4, 5, 6, 7, 8],
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma", "Frank", "Grace", "Helen"],
    "Age": [24, 29, np.nan, 35, 28, 31, np.nan, 26],
    "Department": ["HR", "IT", "Finance", np.nan, "Marketing", "IT", "HR", "Finance"],
    "Salary": [45000, 52000, 61000, 58000, np.nan, 54000, 47000, np.nan]
})

# %%
#sort on nan values
df.sort_values('Age',ascending=True,na_position='first')
# Out:
#    ID     Name   Age Department   Salary
# 2   3  Charlie   NaN    Finance  61000.0
# 6   7    Grace   NaN         HR  47000.0
# 0   1    Alice  24.0         HR  45000.0
# 7   8    Helen  26.0    Finance      NaN
# 4   5     Emma  28.0  Marketing      NaN
# 1   2      Bob  29.0         IT  52000.0
# 5   6    Frank  31.0         IT  54000.0
# 3   4    David  35.0        NaN  58000.0

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#based on two conditions
movies.sort_values(['year_of_release','title_x'],ascending=[True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(series)
batsman = pd.read_csv('batsman_runs_ipl.csv')
batsman
# Out:
#              batter  batsman_run
# 0    A Ashish Reddy          280
# 1          A Badoni          161
# 2        A Chandila            4
# 3          A Chopra           53
# 4       A Choudhary           25
# ..              ...          ...
# 600      Yash Dayal            0
# 601   Yashpal Singh           47
# 602     Younis Khan            3
# 603    Yuvraj Singh         2754
# 604          Z Khan          117
#
# [605 rows x 2 columns]

# %%
batsman['batting-rank']= batsman['batsman_run'].rank(ascending=False)

batsman.sort_values('batting-rank')
# Out:
#              batter  batsman_run  batting-rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %%
#sort-index
marks = pd.Series(
    [85, 90, 78, 92, 88],
    index=["Math", "Physics", "Chemistry", "English", "Computer Science"]
)

# %%
marks.sort_index(ascending=False)
# Out:
# Physics             90
# Math                85
# English             92
# Computer Science    88
# Chemistry           78
# dtype: int64

# %%
#set-index
batsman.set_index('batter',inplace=True)

# %%
batsman
# Out:
#                 batsman_run  batting-rank
# batter
# A Ashish Reddy          280         166.5
# A Badoni                161         226.0
# A Chandila                4         535.0
# A Chopra                 53         329.0
# A Choudhary              25         402.5
# ...                     ...           ...
# Yash Dayal                0         594.0
# Yashpal Singh            47         343.0
# Younis Khan               3         547.5
# Yuvraj Singh           2754          27.0
# Z Khan                  117         256.0
#
# [605 rows x 2 columns]

# %%
#reset-index
batsman.reset_index('batter')
# Out:
#              batter  batsman_run  batting-rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.set_index('batting-rank')
# Out:
#               batsman_run
# batting-rank
# 166.5                 280
# 226.0                 161
# 535.0                   4
# 329.0                  53
# 402.5                  25
# ...                   ...
# 594.0                   0
# 343.0                  47
# 547.5                   3
# 27.0                 2754
# 256.0                 117
#
# [605 rows x 1 columns]

# %%
batsman.reset_index('batter')
# Out:
#              batter  batsman_run  batting-rank
# 0    A Ashish Reddy          280         166.5
# 1          A Badoni          161         226.0
# 2        A Chandila            4         535.0
# 3          A Chopra           53         329.0
# 4       A Choudhary           25         402.5
# ..              ...          ...           ...
# 600      Yash Dayal            0         594.0
# 601   Yashpal Singh           47         343.0
# 602     Younis Khan            3         547.5
# 603    Yuvraj Singh         2754          27.0
# 604          Z Khan          117         256.0
#
# [605 rows x 3 columns]

# %%
batsman.set_index('batting-rank',inplace=True)

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
print(movies.columns)
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
movies.set_index('title_y', inplace=True)

movies.rename(
    columns={
        'imdb_id': 'imdb',
        'poster_path': 'link'
    },
    inplace=True
)

# %%
movies
# Out:
#                                                             title_x  \
# title_y
# Uri: The Surgical Strike                   Uri: The Surgical Strike
# Battalion 609                                         Battalion 609
# The Accidental Prime Minister  The Accidental Prime Minister (film)
# Why Cheat India                                     Why Cheat India
# Evening Shadows                                     Evening Shadows
# ...                                                             ...
# Tera Mera Saath Rahen                         Tera Mera Saath Rahen
# Yeh Zindagi Ka Safar                           Yeh Zindagi Ka Safar
# Sabse Bada Sukh                                     Sabse Bada Sukh
# Daaka                                                         Daaka
# Humsafar                                                   Humsafar
#
#                                      imdb  \
# title_y
# Uri: The Surgical Strike        tt8291224
# Battalion 609                   tt9472208
# ...

# %%
#changing in index
movies.rename(index={'Uri: The Surgical Strike':'URI'})
# Out:
#                                                             title_x  \
# title_y
# URI                                        Uri: The Surgical Strike
# Battalion 609                                         Battalion 609
# The Accidental Prime Minister  The Accidental Prime Minister (film)
# Why Cheat India                                     Why Cheat India
# Evening Shadows                                     Evening Shadows
# ...                                                             ...
# Tera Mera Saath Rahen                         Tera Mera Saath Rahen
# Yeh Zindagi Ka Safar                           Yeh Zindagi Ka Safar
# Sabse Bada Sukh                                     Sabse Bada Sukh
# Daaka                                                         Daaka
# Humsafar                                                   Humsafar
#
#                                      imdb  \
# title_y
# URI                             tt8291224
# Battalion 609                   tt9472208
# ...

# %%
#unique
ipl['Season'].unique()
# Out:
# array(['2022', '2021', '2020/21', '2019', '2018', '2017', '2016', '2015',
#        '2014', '2013', '2012', '2011', '2009/10', '2009', '2007/08'],
#       dtype=object)

# %%
#nunique->doesnt count nan values
ipl["Season"].nunique()
# Out:
# 15

# %%
#hasnans
ipl['Season'].hasnans
# Out:
# False

# %%
ipl.isnull()
# Out:
#         ID   City   Date  Season  MatchNumber  Team1  Team2  Venue  \
# 0    False  False  False   False        False  False  False  False
# 1    False  False  False   False        False  False  False  False
# 2    False  False  False   False        False  False  False  False
# 3    False  False  False   False        False  False  False  False
# 4    False  False  False   False        False  False  False  False
# ..     ...    ...    ...     ...          ...    ...    ...    ...
# 945  False  False  False   False        False  False  False  False
# 946  False  False  False   False        False  False  False  False
# 947  False  False  False   False        False  False  False  False
# 948  False  False  False   False        False  False  False  False
# 949  False  False  False   False        False  False  False  False
#
#      TossWinner  TossDecision  SuperOver  WinningTeam  WonBy  Margin  method  \
# 0         False         False      False        False  False   False    True
# ...

# %%
ipl.notnull()
# Out:
#        ID  City  Date  Season  MatchNumber  Team1  Team2  Venue  TossWinner  \
# 0    True  True  True    True         True   True   True   True        True
# 1    True  True  True    True         True   True   True   True        True
# 2    True  True  True    True         True   True   True   True        True
# 3    True  True  True    True         True   True   True   True        True
# 4    True  True  True    True         True   True   True   True        True
# ..    ...   ...   ...     ...          ...    ...    ...    ...         ...
# 945  True  True  True    True         True   True   True   True        True
# 946  True  True  True    True         True   True   True   True        True
# 947  True  True  True    True         True   True   True   True        True
# 948  True  True  True    True         True   True   True   True        True
# 949  True  True  True    True         True   True   True   True        True
#
# ...

# %%
ipl.hasnans
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16012\2765213492.py in ?()
# ----> 1 ipl.hasnans
#
# ~\AppData\Roaming\Python\Python314\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'hasnans'

# %%
data = {
    "Name": ["Rahul", "Ananya", "Vikram", "Priya", np.nan],
    "Age": [21, 22, np.nan, 20, 23],
    "Marks": [85, np.nan, 78, 92, 88],
    "City": ["Kolkata", "Delhi", np.nan, "Mumbai", "Chennai"],
    "Passed": [True, True, False, np.nan, True]
}

df = pd.DataFrame(data)

print(df)
# Out:
#      Name   Age  Marks     City Passed
# 0   Rahul  21.0   85.0  Kolkata   True
# 1  Ananya  22.0    NaN    Delhi   True
# 2  Vikram   NaN   78.0      NaN  False
# 3   Priya  20.0   92.0   Mumbai    NaN
# 4     NaN  23.0   88.0  Chennai   True

# %%
df.dropna()
# Out:
#    ID   Name   Age Department   Salary
# 0   1  Alice  24.0         HR  45000.0
# 1   2    Bob  29.0         IT  52000.0
# 5   6  Frank  31.0         IT  54000.0

# %%
df.fillna(0)
# Out:
#    ID     Name   Age Department   Salary
# 0   1    Alice  24.0         HR  45000.0
# 1   2      Bob  29.0         IT  52000.0
# 2   3  Charlie   0.0    Finance  61000.0
# 3   4    David  35.0          0  58000.0
# 4   5     Emma  28.0  Marketing      0.0
# 5   6    Frank  31.0         IT  54000.0
# 6   7    Grace   0.0         HR  47000.0
# 7   8    Helen  26.0    Finance      0.0

# %%
df.dropna(how='all')
#only removes the row with all atributes as missing values
# Out:
#      Name   Age  Marks     City Passed
# 0   Rahul  21.0   85.0  Kolkata   True
# 1  Ananya  22.0    NaN    Delhi   True
# 2  Vikram   NaN   78.0      NaN  False
# 3   Priya  20.0   92.0   Mumbai    NaN
# 4     NaN  23.0   88.0  Chennai   True

# %%
# df.dropna(subset=['Department'])
df.dropna(subset=['City'])#drops the row where city is missing
# Out:
#      Name   Age  Marks     City Passed
# 0   Rahul  21.0   85.0  Kolkata   True
# 1  Ananya  22.0    NaN    Delhi   True
# 3   Priya  20.0   92.0   Mumbai    NaN
# 4     NaN  23.0   88.0  Chennai   True

# %%
df['Name'].fillna('Unknown')
# Out:
# 0      Rahul
# 1     Ananya
# 2     Vikram
# 3      Priya
# 4    Unknown
# Name: Name, dtype: object

# %%
df['Name'].fillna(method='ffill')#forward fills
# Out:
# C:\Users\SWAPNEEL SARKAR\AppData\Local\Temp\ipykernel_13400\3798780086.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Name'].fillna(method='ffill')
# 0     Rahul
# 1    Ananya
# 2    Vikram
# 3     Priya
# 4     Priya
# Name: Name, dtype: object

# %%
#drop-duplicates


data = {
    'Name': ['Rahul', 'Amit', 'Rahul', 'Sneha', 'Amit'],
    'Age': [20, 21, 20, 22, 21],
    'Department': ['CSE', 'IT', 'CSE', 'ECE', 'IT']
}

df = pd.DataFrame(data)

print(df)
# Out:
#     Name  Age Department
# 0  Rahul   20        CSE
# 1   Amit   21         IT
# 2  Rahul   20        CSE
# 3  Sneha   22        ECE
# 4   Amit   21         IT

# %%
df.drop_duplicates(keep='last')
# Out:
#     Name  Age Department
# 2  Rahul   20        CSE
# 3  Sneha   22        ECE
# 4   Amit   21         IT

# %%
#last match played by Virat Kohli in IPL in Delhi
ipl['all_players']=ipl['Team1Players']+ipl['Team2Players']
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
def did_kohli_play(list):
    return 'V Kohli' in list

# %%
ipl['kohli_played']=ipl['all_players'].apply(did_kohli_play)
ipl[(ipl['kohli_played']==True)&(ipl['City']=='Delhi')].drop_duplicates(subset=['City','kohli_played'])
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     kohli_played
# 208         True
#
# [1 rows x 22 columns]

# %%
#drop
#cols
ipl.drop(columns=['City'])
# Out:
#           ID        Date   Season  MatchNumber                        Team1  \
# 0    1312200  2022-05-29     2022        Final             Rajasthan Royals
# 1    1312199  2022-05-27     2022  Qualifier 2  Royal Challengers Bangalore
# 2    1312198  2022-05-25     2022   Eliminator  Royal Challengers Bangalore
# 3    1312197  2022-05-24     2022  Qualifier 1             Rajasthan Royals
# 4    1304116  2022-05-22     2022           70          Sunrisers Hyderabad
# ..       ...         ...      ...          ...                          ...
# 945   335986  2008-04-20  2007/08            4        Kolkata Knight Riders
# 946   335985  2008-04-20  2007/08            5               Mumbai Indians
# 947   335984  2008-04-19  2007/08            3             Delhi Daredevils
# 948   335983  2008-04-19  2007/08            2              Kings XI Punjab
# 949   335982  2008-04-18  2007/08            1  Royal Challengers Bangalore
#
# ...
