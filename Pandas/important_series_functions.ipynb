# %%
import numpy as np
import pandas as pd

# %%
ipl = pd.read_csv('kohli_ipl.csv',index_col='match_no')
ipl = ipl.squeeze()

# %%
movies = pd.read_csv('bollywood.csv',index_col='movie')
movies = movies.squeeze()

# %%
#astype
import sys
sys.getsizeof(ipl)
# Out:
# 3472

# %%
sys.getsizeof(ipl.astype('int8'))
# Out:
# 1967

# %%
#between
ipl[ipl.between(50,200)].size
# Out:
# 50

# %%
#clip
temp = pd.Series([1,4,5,6,4,2,3,5,7,8])
temp.clip(4,7)
# Out:
# 0    4
# 1    4
# 2    5
# 3    6
# 4    4
# 5    4
# 6    4
# 7    5
# 8    7
# 9    7
# dtype: int64

# %%
temp = pd.Series([1,2,3,1,2,4,5,6,3,3])
temp.drop_duplicates()
# Out:
# 0    1
# 1    2
# 2    3
# 5    4
# 6    5
# 7    6
# dtype: int64

# %%
temp.drop_duplicates(keep='last')
# Out:
# 3    1
# 4    2
# 5    4
# 6    5
# 7    6
# 9    3
# dtype: int64

# %%
temp.duplicated().sum()
# Out:
# np.int64(4)

# %%
temp = pd.Series([1,2,3,np.nan,4,5,np.nan])
print(temp.size)#nulls+notnulls
print(temp.count())#non nulls only
# Out:
# 7
# 5

# %%
temp.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 4    4.0
# 5    5.0
# dtype: float64

# %%
temp.fillna(89)
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3    89.0
# 4     4.0
# 5     5.0
# 6    89.0
# dtype: float64

# %%
#isin
ipl.isin([34,56,49,99])
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213    False
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %%
#apply (!important)
movies.apply(lambda x : x.split()[0].lower())
# Out:
# movie
# Uri: The Surgical Strike                  vicky
# Battalion 609                             vicky
# The Accidental Prime Minister (film)     anupam
# Why Cheat India                          emraan
# Evening Shadows                            mona
#                                          ...
# Hum Tumhare Hain Sanam                     shah
# Aankhen (2002 film)                     amitabh
# Saathiya (film)                           vivek
# Company (film)                             ajay
# Awara Paagal Deewana                     akshay
# Name: lead, Length: 1500, dtype: object

# %%
ipl.apply(lambda x : 'Wow' if x>49 else 'Ok')
# Out:
# match_no
# 1       Ok
# 2       Ok
# 3       Ok
# 4       Ok
# 5       Ok
#       ...
# 211     Ok
# 212     Ok
# 213    Wow
# 214     Ok
# 215     Ok
# Name: runs, Length: 215, dtype: object

# %%
#copy
new = ipl.head().copy()
